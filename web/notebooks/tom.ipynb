# %%
import dbutils

# %%
db = dbutils.DBConnect('glossify.io', 'tlemberg', 'tlemberg')
# Out:
# mongodb://tlemberg:tlemberg@glossify.io/tenk

# %%
[doc for doc in db.phrases_fr.find({'tags': 'home'})]
# Out:
# [{u'_id': ObjectId('56803e3dbb3357b241f2d83f'),
#   u'base': u'porte',
#   u'count': 54866,
#   u'rank': 263,
#   u'tags': [u'home'],
#   u'txs': [u'door']},
#  {u'_id': ObjectId('56803e4e08d5e57703a21f99'),
#   u'base': u'domicile',
#   u'count': 119445,
#   u'rank': 1045,
#   u'tags': [u'home'],
#   u'txs': [u'home']},
#  {u'_id': ObjectId('56803e4f08d5e57703a22113'),
#   u'base': u'fen\xeatre',
#   u'count': 12924,
#   u'rank': 1423,
#   u'tags': [u'home'],
#   u'txs': [u'window']},
#  {u'_id': ObjectId('56803e3dbb3357b241f2d7ec'),
#   u'base': u'maison',
#   u'count': 80471,
#   u'rank': 180,
#   u'tags': [u'home'],
#   u'txs': [u'House', u'house']}]

# %%
db.collection_names()
# Out:
# [u'sections',
#  u'system.indexes',
#  u'phrase_counts',
#  u'phrases',
#  u'user_profiles',
#  u'user_progress',
#  u'phrases_ru',
#  u'phrases_es',
#  u'phrases_he',
#  u'phrases_sw',
#  u'phrases_is',
#  u'phrases_zh',
#  u'phrases_fr',
#  u'phrases_bn',
#  u'phrases_eo',
#  u'phrases_hi',
#  u'phrases_pt',
#  u'phrases_de',
#  u'phrases_ja',
#  u'phrases_ar',
#  u'phrases_ko',
#  u'phrases_cy',
#  u'translations_zh',
#  u'excerpts',
#  u'documents',
#  u'word_list_es_forward',
#  u'word_list_es_reverse',
#  u'word_list_es',
#  u'translations_es',
#  u'word_list_fr_forward',
#  u'word_list_fr_reverse',
#  u'translations_fr']

# %%
[doc for doc in db.phrases_fr.find()]
# Out:
# [{u'_id': ObjectId('568193f0bb3357d7492cdc64'),
#   u'base': u'est',
#   u'count': 1496575,
#   u'rank': 2,
#   u'tags': [],
#   u'txs': [{u'text': u'is'}]},
#  {u'_id': ObjectId('568193f0bb3357d7492cdc65'),
#   u'base': u'pas',
#   u'count': 864776,
#   u'rank': 3,
#   u'tags': [],
#   u'txs': [{u'text': u'not'}]},
#  {u'_id': ObjectId('568193f0bb3357d7492cdc66'),
#   u'base': u'le',
#   u'count': 1093232,
#   u'rank': 4,
#   u'tags': [],
#   u'txs': [{u'text': u'the'}]},
#  {u'_id': ObjectId('568193f0bb3357d7492cdc67'),
#   u'base': u'vous',
#   u'count': 1043411,
#   u'rank': 5,
#   u'tags': [],
#   u'txs': [{u'text': u'you'}]},
#  {u'_id': ObjectId('568193f0bb3357d7492cdc69'),
#   u'base': u'tu',
#   u'count': 927396,
#   u'rank': 6,
#   u'tags': [],
#   u'txs': [{u'text': u'you'}]},
#  {u'_id': ObjectId('568193f0bb3357d7492cdc6d'),
#   u'base': u'et',
#   u'count': 2127187,
#   u'rank': 8,
#   u'tags': [],
#   u'txs': [{u'text': u'and'}]},
# ...

# %%
db.documents.find()[0]
# Out:
# {u'_id': ObjectId('55edf60e04c84b5f931e3814'),
#  u'email': u'tlemberg10@gmail.next',
#  u'lang': u'zh',
#  u'text': u'\u4eca\u5929\uff0c\u771f\u662f\u4e2a\u91ce\u9910\u7684\u597d\u65e5\u5b50\u3002 \u732a\u5148\u751f\u7cbe\u5fc3\u6253\u626e\u7740\u81ea\u5df1\uff0c\u4ed6\u671f\u5f85\u7740\u732a\u5c0f\u59d0\u80fd\u4e0e\u4ed6\u4e00\u8d77\u53bb\u91ce\u9910\u3002',
#  u'title': u'Mr. Pig'}

# %%
db.excerpts.find()[0]
# Out:
# {u'_id': ObjectId('55ee002f04c84b61a3f1ebe1'),
#  u'document_id': ObjectId('55ee002f04c84b61a3f1ebcf'),
#  u'email': u'tlemberg10@gmail.new',
#  u'excerpt': u'\u201c\u80fd\u6709\u5e78\u8bf7\u4f60\u4e00\u8d77\u53bb\u91ce\u9910\u5417\uff1f\u201d\u4ed6\u95ee',
#  u'lang': u'zh',
#  u'phrase_ids': [ObjectId('55ca87fa04c84b0a84370142'),
#   ObjectId('557da539bb345072f41154c1'),
#   ObjectId('557da539bb345072f41168d9'),
#   ObjectId('557da539bb345072f4115d13'),
#   ObjectId('557da539bb345072f41156da'),
#   ObjectId('557da539bb345072f411514e'),
#   ObjectId('55ca87f904c84b0a8436ee94'),
#   ObjectId('557da539bb345072f41152ef'),
#   ObjectId('557da539bb345072f4115449'),
#   ObjectId('557da539bb345072f4115194')]}
